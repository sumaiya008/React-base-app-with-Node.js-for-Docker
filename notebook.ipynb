# %%
# # in terminal code this step by step to create react base app
# node -v 
# npx create-react-app doc_test_app
# cd doc_test_app
# npm start

# # if it does not work then type
# unset HOST
# set HOST=
# npm start

# # you can go to src > app.js an then edit the Edit thing to show that text to browser
# # you can delete node_module folder to save space and whenever needed you just simply insta it by typing
# npm install
# # after this node_module folder will come back

# # then will be creting a docker file

# #after making docker file now creating image and run these into terminal
# docker build .
# # after making it check llist by
# docker image ls

# # now we will be creating a container with images
# # we will need image \ID from docker image ls and then
# docker run 556653f58ea5
# # now we wont be able to run the app because it's on container for that open new terminal
# cd doc_test_app
# docker ps
# docker stop hopeful_noyce
# docker ps

# # after this go back to our old terminal than
# docker image ls

# # now we need to give accese tha app outside of container for that
# docker run -p 3000:3000 556653f58ea5

# # after running container terminal gets stuck, now we want to make it as it can run on background and do not stuck our terminal for that we can do
# # open new terminal and than
# cd doc_test_app
# docker ps
# docker stop (container name)
# # than go to old terminal and then
# docker run -d -p 3000:3000 556653f58ea5
# # than our terminal will be free and docker is running in the backgroud

# ## running multiple container from single image
# docker run -d -p 3001:3000 556653f58ea5
# docker run -d -p 3002:3000 556653f58ea5
# docker ps

# # if you want to check all container than
# docker ps -a

# # if you want to remove container 
# docker rm (name)

# # if you want to run a containeer and than when you stop it it be removed automaticall
# docker run -d --rm -p 3000:3000 556653f58ea5

## making container name into own custom name
# docker run -d --rm --name "sumaiya app" -p 3000:3000 556653f58ea5

### managing image 
## naming imageId
# docker build -t mydoctestapp:01 .
# docker image ls

## delete images
# docker rmi mydoctestapp:01
# docker image ls

# %%
### update our project

## update that src aap.js Edit option and save it
# docker image ls
# docker buid -t mydoctestapp:02 .
# docker image ls
# docer run -d --rm --name "sumaiya app" -p 3000:3000 mydoctestapp:02
# docker ps

## p

# %%
### PRe defined images from docker hub
# docker pull nginx
# docker run -p 8080:80 nginx:latest
## than you can to to local host and check

# %%
### how to use python program in docker
## firts make a new folder creat vertual environment and than after creating pogram myapp.py create docker file
## remember we only need tha .py to copy not everything else

# docke buidl .
# docker image ls
# docker run (id)

## but if it's a interective code it will not run for that we need to 
# docker run -it (id)

# %%
### how to share images
## after creating acc into docker hub creae you profile and all thing and than
# docker login
## than copy the comman showing on docker hub
# docker images
## name new image on same name
# docker build -t philippaul/webapp-demo:01 .
# docker images
# docker push phi.......

#3 we can also rename our old images name
